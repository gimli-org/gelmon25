# %%
import numpy as np
import matplotlib.pyplot as plt
import pygimli as pg
from pygimli.physics import ert

# %%
tl = ert.CrossholeERT("heat.shm")
print(tl)
# Out:
# Crosshole (8 boreholes) Timelapse ERT data:
# Data: Sensors: 128 data: 3228, nonzero entries: ['a', 'b', 'k', 'm', 'n', 'na', 'nb', 'nm', 'nn', 'valid']
# 47 time steps from 2021-08-10 00:00 to 2021-10-18 00:00

# %%
plt.plot(pg.x(tl.data), pg.y(tl.data), "x");

# %%
ert.showData?
# Out:
# Signature: ert.showData(data, vals=None, **kwargs)
# Docstring:
# Plot ERT data as pseudosection matrix (position over separation).
#
# Creates figure, axis and draw a pseudosection.
#
# Parameters
# ----------
# data : :gimliapi:`BERT::DataContainerERT`
#
# **kwargs :
#
#     * vals : array[nData] | str
#         Values to be plotted. Default is data['rhoa'].
#         Can be array or string whose data field is extracted.
#     * axes : matplotlib.axes
#         Axes to plot into. By default (None), a new figure with
#         a single Axes is created.
#     * x and y : str | list(str)
#         forces using matrix plot (drawDataContainerAsMatrix)
#         x, y define the electrode number on x and y axis
#         can be strings ("a", "m", "mid", "sep") or lists of them ["a", "m"]
#     * style : str
#         predefined styles for choosing x and y arguments (x/y overrides)
#         - "ab-mn" (default):  any combination of current/potential electrodes
#         - "a-m" : only a and m electrode (for unique dipole spacings like DD)
#         - "a-mn" : a and combination of mn electrode (PD with different MN)
#         - "ab-m" : a and combination of mn electrode
#         - "sepa-m" : current dipole length with a and m (multi-gradient)
#         - "a-sepm" : a and potential dipole length with m
#     * switchxy : bool
#         exchange x and y axes before plotting
#
# Returns
# -------
# ax : matplotlib.axes
#     axis containing the plots
# cb : matplotlib.colorbar
#     colorbar instance
# File:      c:\src\gimli\gimli\pygimli\physics\ert\visualization.py
# Type:      function

# %%
tl.showData(t=0);
# Out:
# 16/02/25 - 07:59:08 - pyGIMLi - INFO - found 128 x values
# 16/02/25 - 07:59:08 - pyGIMLi - INFO - found 128 y values
# 16/02/25 - 07:59:08 - pyGIMLi - INFO - x vector length: 3228
# 16/02/25 - 07:59:08 - pyGIMLi - INFO - y vector length: 3228
# 16/02/25 - 07:59:08 - pyGIMLi - INFO - v vector length: 3228
# 16/02/25 - 07:59:08 - pyGIMLi - INFO - 1082 data of 3228 not shown

# %%
# tl.automask()
tl.mask(rmin=50, rmax=300)
tl.showData(t=0);
# Out:
# 16/02/25 - 08:01:09 - pyGIMLi - INFO - found 128 x values
# 16/02/25 - 08:01:09 - pyGIMLi - INFO - found 128 y values
# 16/02/25 - 08:01:09 - pyGIMLi - INFO - x vector length: 3228
# 16/02/25 - 08:01:09 - pyGIMLi - INFO - y vector length: 3228
# 16/02/25 - 08:01:09 - pyGIMLi - INFO - v vector length: 3228
# 16/02/25 - 08:01:09 - pyGIMLi - INFO - 1082 data of 3228 not shown

# %%
h1 = tl.extractSubset([1])

# %%
h1.showData(t=0, style=None, equidistant=True);

# %%
h1.showTimeline(a=10);

# %%
h1.generateDataPDF(style=None, cMin=50, cMax=100, equidistant=True);

# %%
xh2d = tl.extractSubset([1, 2])
print(xh2d)
# Out:
# Crosshole (2 boreholes) Timelapse ERT data:
# Data: Sensors: 32 data: 500, nonzero entries: ['a', 'b', 'k', 'm', 'n', 'na', 'nb', 'nm', 'nn', 'valid']
# 47 time steps from 2021-08-10 00:00 to 2021-10-18 00:00

# %%
xh2d.showData(t=10);
# Out:
# 16/02/25 - 11:12:46 - pyGIMLi - INFO - found 32 x values
# 16/02/25 - 11:12:46 - pyGIMLi - INFO - found 32 y values
# 16/02/25 - 11:12:46 - pyGIMLi - INFO - x vector length: 500
# 16/02/25 - 11:12:46 - pyGIMLi - INFO - y vector length: 500
# 16/02/25 - 11:12:46 - pyGIMLi - INFO - v vector length: 500
# 16/02/25 - 11:12:46 - pyGIMLi - INFO - 136 data of 500 not shown

# %%
xh2d.showTimeline(a=31);

# %%
xh2d.data.sensors().array()
# Out:
# array([[  0.        ,   0.        , -14.        ],
#        [  0.        ,   0.        , -13.5       ],
#        [  0.        ,   0.        , -13.        ],
#        [  0.        ,   0.        , -12.5       ],
#        [  0.        ,   0.        , -12.        ],
#        [  0.        ,   0.        , -11.5       ],
#        [  0.        ,   0.        , -11.        ],
#        [  0.        ,   0.        , -10.5       ],
#        [  0.        ,   0.        , -10.        ],
#        [  0.        ,   0.        ,  -9.5       ],
#        [  0.        ,   0.        ,  -9.        ],
#        [  0.        ,   0.        ,  -8.5       ],
#        [  0.        ,   0.        ,  -8.        ],
#        [  0.        ,   0.        ,  -7.5       ],
#        [  0.        ,   0.        ,  -7.        ],
#        [  0.        ,   0.        ,  -6.5       ],
#        [  2.18862194,   0.        , -14.        ],
#        [  2.18862194,   0.        , -13.5       ],
#        [  2.18862194,   0.        , -13.        ],
#        [  2.18862194,   0.        , -12.5       ],
#        [  2.18862194,   0.        , -12.        ],
#        [  2.18862194,   0.        , -11.5       ],
#        [  2.18862194,   0.        , -11.        ],
#        [  2.18862194,   0.        , -10.5       ],
#        [  2.18862194,   0.        , -10.        ],
#        [  2.18862194,   0.        ,  -9.5       ],
#        [  2.18862194,   0.        ,  -9.        ],
#        [  2.18862194,   0.        ,  -8.5       ],
#        [  2.18862194,   0.        ,  -8.        ],
#        [  2.18862194,   0.        ,  -7.5       ],
#        [  2.18862194,   0.        ,  -7.        ],
#        [  2.18862194,   0.        ,  -6.5       ]])

# %%
xh2d.createMesh()
# Out:
# 16/02/25 - 11:14:35 - pyGIMLi - INFO - Found 2 regions.
# 16/02/25 - 11:14:35 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.

# %%
xh2d.invert(t=0)
# Out:
# 16/02/25 - 11:14:48 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 16/02/25 - 11:14:48 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 16/02/25 - 11:14:48 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 4114 Cells: 8140 Boundaries: 6148
# 16/02/25 - 11:14:48 - pyGIMLi - INFO - Setting starting model as reference!
